# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import scipy.optimize
# %matplotlib inline

# %%
x = np.linspace(-3, 3, 300)
y = np.linspace(-2, 2, 200)
X, Y = np.meshgrid(x, y)
F1 = X**4 + Y**4-15
F2=X**3*Y - X*Y**3 - Y/2 - 1.937
plt.clf()
#plt.imshow(Z, origin='lower', cmap=cm.viridis, extent=(-3, 3, -2, 2))

levels = [0]
plt.contour(X, Y, F1, levels)
plt.contour(X, Y, F2, levels)

plt.xlabel('$x$', fontsize=18)
plt.ylabel('$y$', fontsize=18)
plt.title('Funciones F1 y F2 en nivel cero')

# %%
### Busqueda de la wea 
t=np.linspace(-np.pi,np.pi,300)

# %%
xt=15**(1/4.)*np.sign(np.sin(t))*(np.sin(t)*np.sin(t))**(1/4.)
yt=15**(1/4.)*np.sign(np.cos(t))*(np.cos(t)*np.cos(t))**(1/4.)

#xt=15**(1/4.)*(np.sin(t)*np.sin(t))**(1/4.)
#yt=15**(1/4.)*(np.cos(t)*np.cos(t))**(1/4.)


X, Y = np.meshgrid(xt, yt)
F1 = X**4 + Y**4-15
F2=X**3*Y - X*Y**3 - Y/2 - 1.937
plt.clf()

##### Weas para ver t
pi_4=[x[i]*(-1)*(np.tan(np.pi*(1/4.)))**(1/2.) for i in range(300)]


#xs=[15**(1/4.)*(np.sin(np.pi/4))**(1/2.) for i in range(300)]
#yc=[15**(1/4.)*(np.sin(np.pi/4))**(1/2.) for i in range(300)]
x1=[x[i] for i in range(300)]
y1=[y[i] for i in range(200)]
#####

levels = [0]
plt.contour(X, Y, F1, levels)
plt.contour(X, Y, F2, levels)

## Plots mios
plt.plot(x1,pi_4)
#plt.plot(x1,xs,'g')



plt.xlabel('$x$', fontsize=18)
plt.ylabel('$y$', fontsize=18)
plt.xlim(-2.5,2.5)
plt.ylim(-2.5,2.5)
plt.title('Funciones F1 y F2 en nivel cero')

# %%
def f2(to):
    t=np.linspace(-np.pi,np.pi,300.)
    xt=15**(1/4.)*np.sign(np.sin(t))*(np.sin(t)*np.sin(t))**(1/4.)
    yt=15**(1/4.)*np.sign(np.cos(t))*(np.cos(t)*np.cos(t))**(1/4.)
    j=0
    e=2*np.pi/300
    for i in range(np.shape(t)[0]):
        if abs(to-i)<=e:
            j=i
    
    F2=xt[j]**3*yt[j] - xt[j]*yt[j]**3 - yt[j]/2 - 1.937


a=scipy.optimize.bisect(f2,np.pi/4,np.pi/7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-157-ccf8bb4cd8a5> in <module>()
#      12
#      13
# ---> 14 a=scipy.optimize.bisect(f2,np.pi/4,np.pi/7)
#
# /home/sergio/anaconda2/lib/python2.7/site-packages/scipy/optimize/zeros.pyc in bisect(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     246     if rtol < _rtol:
#     247         raise ValueError("rtol too small (%g < %g)" % (rtol, _rtol))
# --> 248     r = _zeros._bisect(f,a,b,xtol,rtol,maxiter,args,full_output,disp)
#     249     return results_c(full_output, r)
#     250
#
# <ipython-input-157-ccf8bb4cd8a5> in f2(to)
#       1 def f2(to):
# ----> 2     t=np.linspace(-np.pi,np.pi,300.)
#       3     xt=15**(1/4.)*np.sign(np.sin(t))*(np.sin(t)*np.sin(t))**(1/4.)
#       4     yt=15**(1/4.)*np.sign(np.cos(t))*(np.cos(t)*np.cos(t))**(1/4.)
#       5     j=0
#
# /home/sergio/anaconda2/lib/python2.7/site-packages/numpy/core/function_base.pyc in linspace(start, stop, num, endpoint, retstep, dtype)
#      91     stop = stop * 1.
#      92
# ---> 93     dt = result_type(start, stop, float(num))
#      94     if dtype is None:
#      95         dtype = dt
#
# TypeError: a float is required

# %%
np.shape(t)
# Out:
# (300,)
